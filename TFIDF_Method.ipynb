# %% [markdown]
# # IST-718: Big Data Analysis Project<br>
# # Political Ideologies Prediction in News Articles

# %% [markdown]
# ### Group-5 <br>
# ### Sharvil Deepak Arjunwadkar
# ### Aadil Zikre
# ### Harmish Doshi

# %% [markdown]
# Instructions:<br>
# 1) Please update the path in the import data section to where you have stored the json file<br>
# 2) Also update the path in the implementation section to where you have stored the 2 trained models<br>
# 3) If you just want to see the implementation only, please do not run the Stratified Train-Test Split, Multinomial Naive Bayes and Random Forest Classifier Section as that will start retraining the model and it will take time.<br>
# 4) If you are running this notebook in Google Colab Free version and you want to retrain the model, run only one model at a time.<br>

# %% [markdown]
# This notebook contains code for implementation of prediction model to classify a news article as "left", "right" and "center" biased. Following are the contents of this notebook:<br>
# <br>
# 1) Setup: Install all packages and dependencies including Spark-NLP and compatible version of pyspark, pynytimes (for NYT API) etc.<br>
# 2) Import Data : Import the JSON file<br>
# 3) Initilize All Annotators in Spark-NLP<br>
# 4) Setup a Preprocessing Pipeline<br>
# 5) Stratified Train-Test Split<br>
# 6) Multinomail Naive Bayes (Training Model): Contains Performance Evaluation<br>
# 7) Random Forest Classifier Model (Training Model): Contains Performance Evaluation<br>
# 8) Implementation NYT: Demonstration of application using NYT API, Feature importance for both the models and testing with specific examples

# %% [markdown]
# ### Setup

# %%
#Install PySpark and SparkNLP specific versions (stable versions)
# !pip install spark-nlp==5.1.4 pyspark==3.3.1
# Out:
# Collecting spark-nlp==5.1.4
#   Downloading spark_nlp-5.1.4-py2.py3-none-any.whl (540 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.7/540.7 kB 5.3 MB/s eta 0:00:00
# Collecting pyspark==3.3.1
#   Downloading pyspark-3.3.1.tar.gz (281.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.4/281.4 MB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting py4j==0.10.9.5 (from pyspark==3.3.1)
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 kB 20.9 MB/s eta 0:00:00
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845494 sha256=2bd28a92dfc940eff18fc53e83c08304160892462d5c43dc57ede41b65510e66
#   Stored in directory: /root/.cache/pip/wheels/0f/f0/3d/517368b8ce80486e84f89f214e0a022554e4ee64969f46279b
# Successfully built pyspark
# Installing collected packages: spark-nlp, py4j, pyspark
#   Attempting uninstall: py4j
#     Found existing installation: py4j 0.10.9.7
#     Uninstalling py4j-0.10.9.7:
#       Successfully uninstalled py4j-0.10.9.7
# Successfully installed py4j-0.10.9.5 pyspark-3.3.1 spark-nlp-5.1.4

# %%
# Install nltk
! pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
# Install the package to interact with NYT API
# !pip install pynytimes
# Out:
# Collecting pynytimes
#   Downloading pynytimes-0.10.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: requests<3.0.0,>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from pynytimes) (2.31.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pynytimes) (2.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.10.0->pynytimes) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.10.0->pynytimes) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.10.0->pynytimes) (2023.11.17)
# Installing collected packages: pynytimes
# Successfully installed pynytimes-0.10.0

# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# create Spark Session and Spark Context
from pyspark.sql import SparkSession
#Import sparknlp library
import sparknlp

#Start a sparknlp session
spark = sparknlp.start()

# %%
# Check the spark session information
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://d1d67a246f38:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#Import all the required libraries and packages
from pyspark.sql import functions as F
from pyspark.ml.classification import RandomForestClassificationModel, RandomForestClassifier
from sparknlp.base import DocumentAssembler
from sparknlp.annotator import Tokenizer
from sparknlp.annotator import Normalizer
import nltk
from nltk.corpus import stopwords
from sparknlp.annotator import StopWordsCleaner
from sparknlp.base import Finisher
from pyspark.ml.feature import CountVectorizer
from pyspark.ml.feature import IDF
from pyspark.ml.feature import StringIndexer
from pyspark.ml import Pipeline
from pyspark.ml.classification import NaiveBayes, NaiveBayesModel
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.mllib.evaluation import MulticlassMetrics
import pynytimes
from pynytimes import NYTAPI
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import Data

# %%
# Fetch the data from the source
data_path = '/content/drive/MyDrive/Big Data Analysis/Project/released_data.json'

# spark is an existing SparkSession
data_df = spark.read.json(data_path)

# Displays the content of the DataFrame to stdout
data_df.show()
# Out:
# +-------------+------------------+---------------+--------------------+--------+--------------------+----------------+--------------------+
# |adfontes_fair|adfontes_political|  allsides_bias|             content|event_id|                misc|          source|               title|
# +-------------+------------------+---------------+--------------------+--------+--------------------+----------------+--------------------+
# |         bias|              bias| From the Right|Obama administrat...|       0|{[Brooke Singman,...|        Fox News|Trump blasts Howa...|
# |         bias|           neutral|From the Center|WASHINGTON – Pres...|       0|{[David Jackson],...|       USA TODAY|Trump blasts form...|
# |         bias|           neutral| From the Right|Acting White Hous...|       0|{[], null, null, ...|Washington Times|Mick Mulvaney: Tr...|
# |         bias|           neutral| From the Right|President Trump r...|       0|{[Dave Boyer], nu...|Washington Times|Trump says 'we'll...|
# |         bias|           neutral|From the Center|President Donald ...|       0|{[], null, null, ...|        BBC News|Trump backs down ...|
# |         bias|           neutral|  From the Left|President Donald ...|       0|{[BURGESS EVERETT...|        Politico|‘Complete, total ...|
# |      unknown|           unknown| From the Right|President Donald ...|       0|{[Katie Pavlich, ...|        Townhall|BREAKING: Trump A...|
# |         bias|           neutral|  From the Left|The president has...|       0|{[Li Zhou], null,...|             Vox|Trump caves on sh...|
# |         bias|           neutral|From the Center|President TrumpDo...|       0|{[Jordan Fabian, ...|        The Hill|Trump agrees to e...|
# |         bias|           neutral|  From the Left|Roger Stone, a fo...|       0|{null, null, null...|     NBCNews.com|Ex-Trump adviser ...|
# |         bias|              bias| From the Right|President Trump's...|       0|{[Alex Pappas, | ...|        Fox News|Roger Stone indic...|
# |         bias|           neutral|From the Center|WASHINGTON (Reute...|       0|{[Richard Cowan, ...|         Reuters|Senate seeks solu...|
# |         bias|           neutral|  From the Left|Washington (CNN)T...|       0|{[Eli Watkins], n...|  CNN (Web News)|How senators vote...|
# |         bias|           neutral| From the Right|The Senate on Thu...|       0|{[David Sherfinsk...|Washington Times|Senate rejects Tr...|
# |         bias|           neutral| From the Right|WASHINGTON (Reute...|       0|{[Richard Cowan, ...|Washington Times|Trump delays Stat...|
# |         bias|           neutral|From the Center|WASHINGTON (Reute...|       0|{[Richard Cowan, ...|         Reuters|Trump delays Stat...|
# |         bias|           neutral|  From the Left|President Donald ...|       0|{[Nick Visser, Ni...|        HuffPost|President Donald ...|
# |         bias|           neutral| From the Right|The New York Stat...|       0|{[Alexandra DeSan...| National Review|New York State Se...|
# |         bias|           neutral|  From the Left|New York state ha...|       0|{[], null, null, ...|        CBS News|New York passes l...|
# |      unknown|           unknown|From the Center|ALBANY, N.Y. (AP)...|       0|{[DAVID KLEPPER],...|Associated Press|NY enacts new pro...|
# +-------------+------------------+---------------+--------------------+--------+--------------------+----------------+--------------------+
# only showing top 20 rows

# %%
# Take a subset of the dataframe
news_content = data_df.select(["content", "allsides_bias"])

# %%
# See the label distribution in the dataset
news_content.groupBy("allsides_bias").count().show()
# Out:
# +---------------+-----+
# |  allsides_bias|count|
# +---------------+-----+
# |  From the Left| 3684|
# |From the Center| 1240|
# | From the Right| 2851|
# +---------------+-----+

# %% [markdown]
# ### Initilize All the Annotators in Spark NLP

# %%
# Initilize a document assembler annotator
documentAssembler = DocumentAssembler().setInputCol('content').setOutputCol('document')

# %%
# Tokenize the document
tokenizer = Tokenizer() \
     .setInputCols(['document']) \
     .setOutputCol('tokenized')

# %%
# Normalize the tokens
normalizer = Normalizer() \
                .setInputCols(["tokenized"]) \
                .setOutputCol("normalized") \
                .setLowercase(True) \
                .setMinLength(2)

# %%
# Download the stopwords corpus from nltk
nltk.download('stopwords')

# Store the stopwards corpus in a variable
eng_stopwords = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Initilize a stopwards clenser annotator
stopwords_cleaner = StopWordsCleaner() \
     .setInputCols(['normalized']) \
     .setOutputCol('unigrams') \
     .setStopWords(eng_stopwords)

# %%
# Initilize a finisher annotator
finisher = Finisher() \
     .setInputCols(['unigrams'])

# %%
# Initilize a TF/Count Vectorizer
tfizer = CountVectorizer(inputCol='finished_unigrams', outputCol='tf_features')

# %%
# Initilize an IDF annotator
idfizer = IDF(inputCol='tf_features', outputCol='tf_idf_features')

# %%
# Initilize a string indexer which converts categorical data into quantitative classes
# Majority class takes the first index and so on
# Class 0.0: From the Left
# Class 1.0: From the Right
# Class 2.0: From the Center
indexer = StringIndexer(inputCol="allsides_bias", outputCol="allsides_bias_Index")

# %% [markdown]
# ### Setup a Preprocessing Pipeline

# %%
#Initilize a pipeline
preprocessing_pipline = Pipeline() \
                      .setStages([documentAssembler,
                        tokenizer,
                        normalizer,
                        stopwords_cleaner,
                        finisher,
                        tfizer,
                        idfizer,
                        indexer])

# %%
# Train a pipeline model
preprocessed_model = preprocessing_pipline.fit(news_content)

# Get an output dataframe
preprocessed_df = preprocessed_model.transform(news_content)

# %% [markdown]
# ### Stratified Train-Test Split

# %%
# Stratified Train-Test Split
# Get a grouped distribution of target variables and store the count
target_distribution = preprocessed_df.groupBy("allsides_bias").count().collect()

# Create a dictionary for the target distribution
target_distribution_dict = {row["allsides_bias"]: row["count"] for row in target_distribution}

# Create a fractions dictionary
fractions = {key: 0.8 for key in target_distribution_dict.keys()}

# Print both the dictionaries
print(target_distribution_dict)
print(fractions)
# Out:
# {'From the Left': 3684, 'From the Center': 1240, 'From the Right': 2851}
# {'From the Left': 0.8, 'From the Center': 0.8, 'From the Right': 0.8}

# %%
# Create a stratified train and test datasets
train_data = preprocessed_df.stat.sampleBy("allsides_bias",fractions, 0)
test_data = preprocessed_df.subtract(train_data)

# %%
# Check the distribution of target labels in training dataset
train_data.groupBy("allsides_bias").count().show()
# Out:
# +---------------+-----+
# |  allsides_bias|count|
# +---------------+-----+
# |  From the Left| 2962|
# |From the Center|  998|
# | From the Right| 2222|
# +---------------+-----+

# %%
# Check the distribution of target labels in test dataset
test_data.groupBy("allsides_bias").count().show()
# Out:
# +---------------+-----+
# |  allsides_bias|count|
# +---------------+-----+
# |  From the Left|  718|
# |From the Center|  241|
# | From the Right|  625|
# +---------------+-----+

# %% [markdown]
# ### Multinomial Naive Bayes Model

# %%
# Initilize a MNB Model
# create the trainer and set its parameters
nb = NaiveBayes(smoothing=1.0, modelType="multinomial", featuresCol="tf_idf_features", labelCol="allsides_bias_Index", predictionCol="predictions_nb")

# %%
# Train the model on training dataset
model_mnb = nb.fit(train_data)

# Get predictions for the test dataset
predictions_nb = model_mnb.transform(test_data)

# %% [markdown]
# #### Performance Evaluation

# %%
# compute accuracy on the test set
evaluator = MulticlassClassificationEvaluator(labelCol="allsides_bias_Index", predictionCol="predictions_nb",
                                              metricName="accuracy")
accuracy = evaluator.evaluate(predictions_nb)
print("Test set accuracy = " + str(accuracy))
# Out:
# Test set accuracy = 0.6047979797979798

# %%
# Compute raw scores on the test set
predictionAndLabels_nb = predictions_nb.rdd.map(lambda lp: (lp.predictions_nb, lp.allsides_bias_Index))

# %%
# check
predictionAndLabels_nb.first()
# Out:
# (0.0, 0.0)

# %%
# Instantiate metrics object
metrics_nb = MulticlassMetrics(predictionAndLabels_nb)

# Statistics by class
labels = predictions_nb.rdd.map(lambda lp: lp.allsides_bias_Index).distinct().collect()
for label in sorted(labels):
    print("Class %s precision = %s" % (label, metrics_nb.precision(label)))
    print("Class %s recall = %s" % (label, metrics_nb.recall(label)))
    print("Class %s F1 Measure = %s" % (label, metrics_nb.fMeasure(label)))
# Out:
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/context.py:157: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# Class 0.0 precision = 0.7027027027027027
# Class 0.0 recall = 0.6155988857938719
# Class 0.0 F1 Measure = 0.6562731997030439
# Class 1.0 precision = 0.666095890410959
# Class 1.0 recall = 0.6224
# Class 1.0 F1 Measure = 0.6435070306038048
# Class 2.0 precision = 0.3423180592991914
# Class 2.0 recall = 0.5269709543568465
# Class 2.0 F1 Measure = 0.41503267973856217

# %%
# Calculate the weighted F1 Measure
metrics_nb.weightedFMeasure()
# Out:
# 0.614532151092902

# %%
# Save the model
model_mnb.write().overwrite().save("/content/drive/MyDrive/Big Data Analysis/Project/Trained_Model/tfidf_multi_nb_model")

# %% [markdown]
# ### Random forest Classifier Model

# %%
# Initilize a Random Forest Classification model
r_forest  = RandomForestClassifier(featuresCol='tf_idf_features', labelCol='allsides_bias_Index', predictionCol='prediction_rf', numTrees=100, maxDepth=30)

# %%
# Train the model on the training dataset
rf_model = r_forest.fit(train_data)

# Get predictions for the test dataset
prediction_rf = rf_model.transform(test_data)

# %%
# Check the important parameters used
rf_model.getParam
# Out:
# <bound method Params.getParam of RandomForestClassificationModel: uid=RandomForestClassifier_ae5cc588d857, numTrees=100, numClasses=3, numFeatures=74223>

# %% [markdown]
# #### Performance Evaluation

# %%
# compute accuracy on the test set
evaluator_rf = MulticlassClassificationEvaluator(labelCol="allsides_bias_Index", predictionCol="prediction_rf",
                                              metricName="accuracy")
accuracy_rf = evaluator_rf.evaluate(prediction_rf)
print("Test set accuracy = " + str(accuracy_rf))
# Out:
# Test set accuracy = 0.6824494949494949

# %%
# Compute raw scores on the test set
predictionAndLabels_rf = prediction_rf.rdd.map(lambda lp: (lp.prediction_rf, lp.allsides_bias_Index))

# %%
# Check
predictionAndLabels_rf.first()
# Out:
# (0.0, 0.0)

# %%
# Instantiate metrics object
metrics_rf = MulticlassMetrics(predictionAndLabels_rf)

# Statistics by class
labels_rf = prediction_rf.rdd.map(lambda lp: lp.allsides_bias_Index).distinct().collect()
for label in sorted(labels_rf):
    print("Class %s precision = %s" % (label, metrics_rf.precision(label)))
    print("Class %s recall = %s" % (label, metrics_rf.recall(label)))
    print("Class %s F1 Measure = %s" % (label, metrics_rf.fMeasure(label)))
# Out:
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/context.py:157: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# Class 0.0 precision = 0.603202846975089
# Class 0.0 recall = 0.9442896935933147
# Class 0.0 F1 Measure = 0.7361563517915309
# Class 1.0 precision = 0.8666666666666667
# Class 1.0 recall = 0.5824
# Class 1.0 F1 Measure = 0.6966507177033493
# Class 2.0 precision = 0.975
# Class 2.0 recall = 0.16182572614107885
# Class 2.0 F1 Measure = 0.2775800711743772

# %%
# Calculate the Weighted F1 Measure
metrics_rf.weightedFMeasure()
# Out:
# 0.6507978259494556

# %%
# Save the model
rf_model.write().overwrite().save("/content/drive/MyDrive/Big Data Analysis/Project/Trained_Model/tfidf_random_forest_model")

# %% [markdown]
# ### Implementation: NYT

# %%
# Load the saved Random Forest Classification Model
tf_rf_model = RandomForestClassificationModel.load("/content/drive/MyDrive/Big Data Analysis/Project/Trained_Model/tfidf_random_forest_model")

# Load the saved Multinimoal Naive Bayes Model
tf_mnb_model = NaiveBayesModel.load("/content/drive/MyDrive/Big Data Analysis/Project/Trained_Model/tfidf_multi_nb_model")

# %%
# View the preprocessed training data
preprocessed_df.show()
# Out:
# +--------------------+---------------+--------------------+--------------------+--------------------+-------------------+
# |             content|  allsides_bias|   finished_unigrams|         tf_features|     tf_idf_features|allsides_bias_Index|
# +--------------------+---------------+--------------------+--------------------+--------------------+-------------------+
# |Obama administrat...| From the Right|[obama, administr...|(74223,[0,1,2,4,5...|(74223,[0,1,2,4,5...|                1.0|
# |WASHINGTON – Pres...|From the Center|[washington, pres...|(74223,[0,1,2,3,4...|(74223,[0,1,2,3,4...|                2.0|
# |Acting White Hous...| From the Right|[acting, white, h...|(74223,[0,1,2,3,4...|(74223,[0,1,2,3,4...|                1.0|
# |President Trump r...| From the Right|[president, trump...|(74223,[1,2,3,5,1...|(74223,[1,2,3,5,1...|                1.0|
# |President Donald ...|From the Center|[president, donal...|(74223,[0,1,2,3,4...|(74223,[0,1,2,3,4...|                2.0|
# |President Donald ...|  From the Left|[president, donal...|(74223,[0,1,2,4,5...|(74223,[0,1,2,4,5...|                0.0|
# |President Donald ...| From the Right|[president, donal...|(74223,[0,1,2,4,5...|(74223,[0,1,2,4,5...|                1.0|
# |The president has...|  From the Left|[president, blink...|(74223,[0,1,2,4,5...|(74223,[0,1,2,4,5...|                0.0|
# |President TrumpDo...|From the Center|[president, trump...|(74223,[0,1,2,4,5...|(74223,[0,1,2,4,5...|                2.0|
# |Roger Stone, a fo...|  From the Left|[roger, stone, fo...|(74223,[0,1,2,3,4...|(74223,[0,1,2,3,4...|                0.0|
# |President Trump's...| From the Right|[president, trump...|(74223,[0,1,2,3,4...|(74223,[0,1,2,3,4...|                1.0|
# |WASHINGTON (Reute...|From the Center|[washington, reut...|(74223,[0,1,2,4,5...|(74223,[0,1,2,4,5...|                2.0|
# |Washington (CNN)T...|  From the Left|[washington, cnnt...|(74223,[2,4,13,17...|(74223,[2,4,13,17...|                0.0|
# |The Senate on Thu...| From the Right|[senate, thursday...|(74223,[0,1,2,3,4...|(74223,[0,1,2,3,4...|                1.0|
# |WASHINGTON (Reute...| From the Right|[washington, reut...|(74223,[0,1,2,4,5...|(74223,[0,1,2,4,5...|                1.0|
# |WASHINGTON (Reute...|From the Center|[washington, reut...|(74223,[0,1,2,4,5...|(74223,[0,1,2,4,5...|                2.0|
# |President Donald ...|  From the Left|[president, donal...|(74223,[0,1,2,4,5...|(74223,[0,1,2,4,5...|                0.0|
# |The New York Stat...| From the Right|[new, york, state...|(74223,[9,12,19,3...|(74223,[9,12,19,3...|                1.0|
# |New York state ha...|  From the Left|[new, york, state...|(74223,[0,1,2,4,8...|(74223,[0,1,2,4,8...|                0.0|
# |ALBANY, N.Y. (AP)...|From the Center|[albany, ny, ap, ...|(74223,[0,1,2,4,6...|(74223,[0,1,2,4,6...|                2.0|
# +--------------------+---------------+--------------------+--------------------+--------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# #### Feature Importance - Random Forest Classifier Model

# %%
# Get the output from Count Vectorization/TF stage of the pipeline
count_v = preprocessed_model.stages[5]

# %%
# Extract the vovalulary used by the count vectorizer
vocab = count_v.vocabulary

# %%
# check the vocab
vocab
# Out:
# ['said',
#  'trump',
#  'president',
#  'mr',
#  'would',
#  'house',
#  'us',
#  'obama',
#  'also',
#  'new',
#  'people',
#  'one',
#  'state',
#  'republican',
#  'white',
#  'could',
#  'campaign',
#  'republicans',
#  'states',
#  'senate',
#  'told',
#  'clinton',
#  'time',
#  'democrats',
#  'government',
#  'two',
#  'last',
#  'first',
#  'news',
#  'trumps',
#  'bill',
#  'like',
#  'even',
#  'years',
#  'many',
#  'former',
#  'national',
#  'washington',
#  'year',
#  'american',
#  'administration',
#  'percent',
#  'law',
#  'united',
#  'congress',
#  'security',
#  'political',
#  'officials',
#  'democratic',
#  'going',
#  'get',
#  'federal',
#  'made',
#  'make',
#  'vote',
#  'say',
#  'may',
#  'back',
#  'week',
#  'country',
#  'party',
#  'election',
#  'court',
#  'including',
#  'support',
#  'tuesday',
#  'statement',
#  'department',
#  'think',
#  'day',
#  'report',
#  'according',
#  'tax',
#  'health',
#  'police',
#  'take',
#  'still',
#  'dont',
#  'public',
#  'deal',
#  'called',
#  'since',
#  'way',
#  'committee',
#  'thursday',
#  'gop',
#  'saying',
#  'presidential',
#  'well',
#  'americans',
#  'monday',
#  'office',
#  'whether',
#  'much',
#  'secretary',
#  'work',
#  'voters',
#  'sen',
#  'policy',
#  'friday',
#  'wednesday',
#  'military',
#  'know',
#  'right',
#  'press',
#  'donald',
#  'another',
#  'want',
#  'times',
#  'john',
#  'justice',
#  'north',
#  'care',
#  'immigration',
#  'attack',
#  'debate',
#  'part',
#  'says',
#  'plan',
#  'see',
#  'york',
#  'members',
#  'next',
#  'leaders',
#  'general',
#  'end',
#  'go',
#  'group',
#  'thats',
#  'investigation',
#  'days',
#  'three',
#  'come',
#  'world',
#  'sanders',
#  'leader',
#  'case',
#  'need',
#  'decision',
#  'asked',
#  'media',
#  'russia',
#  'million',
#  'obamas',
#  'official',
#  'among',
#  'night',
#  'without',
#  'long',
#  'issue',
#  'border',
#  'later',
#  'romney',
#  'good',
#  'sunday',
#  'clear',
#  'foreign',
#  'change',
#  'top',
#  'already',
#  'war',
#  'never',
#  'meeting',
#  'cnn',
#  'russian',
#  'speech',
#  'spending',
#  'america',
#  'presidents',
#  'though',
#  'cruz',
#  'added',
#  'took',
#  'came',
#  'several',
#  'likely',
#  'hes',
#  'put',
#  'act',
#  'fox',
#  'reported',
#  'hillary',
#  'use',
#  'help',
#  'fbi',
#  'information',
#  'senator',
#  'rights',
#  'majority',
#  'every',
#  'bush',
#  'intelligence',
#  'director',
#  'point',
#  'conservative',
#  'program',
#  'used',
#  'around',
#  'earlier',
#  'gun',
#  'least',
#  'month',
#  'race',
#  'months',
#  'left',
#  'might',
#  'candidate',
#  'far',
#  'weeks',
#  'didnt',
#  'groups',
#  'action',
#  'family',
#  'reporters',
#  'past',
#  'early',
#  'order',
#  'legislation',
#  'recent',
#  'job',
#  'must',
#  'chief',
#  'attacks',
#  'attorney',
#  'move',
#  'money',
#  'congressional',
#  'power',
#  'women',
#  'control',
#  'morning',
#  'issues',
#  'win',
#  'im',
#  'call',
#  'lawmakers',
#  'show',
#  'place',
#  'wrote',
#  'trade',
#  'nuclear',
#  'four',
#  'syria',
#  'believe',
#  'rep',
#  'comments',
#  'south',
#  'process',
#  'number',
#  'legal',
#  'making',
#  'economic',
#  'yet',
#  'today',
#  'big',
#  'home',
#  'however',
#  'cuts',
#  'executive',
#  'questions',
#  'things',
#  'budget',
#  'released',
#  'defense',
#  'saturday',
#  'set',
#  'major',
#  'senior',
#  'something',
#  'wall',
#  'click',
#  'paul',
#  'force',
#  'interview',
#  'votes',
#  'working',
#  'trying',
#  'agreement',
#  'others',
#  'great',
#  'city',
#  'nations',
#  'better',
#  'second',
#  'system',
#  'jobs',
#  'twitter',
#  'really',
#  'fight',
#  'man',
#  'found',
#  'story',
#  'children',
#  'plans',
#  'workers',
#  'keep',
#  'give',
#  'less',
#  'obamacare',
#  'doesnt',
#  'school',
#  'announced',
#  'question',
#  'supreme',
#  'away',
#  'ms',
#  'read',
#  'enough',
#  'post',
#  'business',
#  'democrat',
#  'little',
#  'killed',
#  'candidates',
#  'billion',
#  'special',
#  'economy',
#  'important',
#  'primary',
#  'done',
#  'expected',
#  'pay',
#  'reports',
#  'possible',
#  'barack',
#  'got',
#  'continue',
#  'service',
#  'weapons',
#  'look',
#  'chairman',
#  'iran',
#  'team',
#  'conference',
#  'florida',
#  'ryan',
#  'response',
#  'effort',
#  'shutdown',
#  'countries',
#  'across',
#  'supporters',
#  'theres',
#  'judge',
#  'fact',
#  'lot',
#  'ago',
#  'korea',
#  'politics',
#  'lead',
#  'run',
#  'nominee',
#  'mrs',
#  'efforts',
#  'late',
#  'senators',
#  'clintons',
#  'history',
#  'international',
#  'become',
#  'high',
#  'close',
#  'face',
#  'continued',
#  'seen',
#  'poll',
#  'began',
#  'address',
#  'hours',
#  'stop',
#  'life',
#  'given',
#  'sessions',
#  'held',
#  'agency',
#  'taking',
#  'texas',
#  'rubio',
#  'reform',
#  'staff',
#  'instead',
#  'nomination',
#  'video',
#  'laws',
#  'nothing',
#  'open',
#  'person',
#  'able',
#  'went',
#  'polls',
#  'email',
#  'insurance',
#  'strong',
#  'view',
#  'nearly',
#  'social',
#  'five',
#  'future',
#  'mcconnell',
#  'despite',
#  'union',
#  'ban',
#  'black',
#  'best',
#  'center',
#  'speaker',
#  'violence',
#  'california',
#  'points',
#  'evidence',
#  'private',
#  'enforcement',
#  'boehner',
#  'known',
#  'governor',
#  'nation',
#  'behind',
#  'coming',
#  'leadership',
#  'spokesman',
#  'immigrants',
#  'position',
#  'china',
#  'university',
#  'comes',
#  'threat',
#  'theyre',
#  'minister',
#  'men',
#  'taken',
#  'rules',
#  'together',
#  'real',
#  'different',
#  'forward',
#  'funding',
#  'families',
#  'current',
#  'led',
#  'march',
#  'pass',
#  'outside',
#  'cant',
#  'getting',
#  'gov',
#  'along',
#  'thing',
#  'mccain',
#  'running',
#  'key',
#  'ahead',
#  'middle',
#  'tweeted',
#  'hard',
#  'full',
#  'islamic',
#  'role',
#  'debt',
#  'policies',
#  'calling',
#  'community',
#  'find',
#  'contributed',
#  'ever',
#  'matter',
#  'local',
#  'iraq',
#  'latest',
#  'comey',
#  'companies',
#  'personal',
#  'proposal',
#  'message',
#  'associated',
#  'final',
#  'hearing',
#  'line',
#  'potential',
#  'civil',
#  'problem',
#  'shooting',
#  'taxes',
#  'israel',
#  'officers',
#  'toward',
#  'wants',
#  'coverage',
#  'talk',
#  'george',
#  'isis',
#  'start',
#  'kavanaugh',
#  'let',
#  'allow',
#  'vice',
#  'sanctions',
#  'young',
#  'sure',
#  'looking',
#  'lost',
#  'within',
#  'needs',
#  'data',
#  'anything',
#  'forces',
#  'authorities',
#  'measure',
#  'elections',
#  'iowa',
#  'district',
#  'services',
#  'company',
#  'passed',
#  'allies',
#  'sent',
#  'carolina',
#  'cut',
#  'following',
#  'hope',
#  'free',
#  'whose',
#  'try',
#  'hold',
#  'record',
#  'november',
#  'side',
#  'often',
#  'calls',
#  'conservatives',
#  'provide',
#  'convention',
#  'kind',
#  'based',
#  'victory',
#  'release',
#  'letter',
#  'six',
#  'west',
#  'actually',
#  'wont',
#  'air',
#  'voted',
#  'actions',
#  'changes',
#  'leave',
#  'illegal',
#  'wanted',
#  'always',
#  'michael',
#  'member',
#  'showed',
#  'rather',
#  'small',
#  'meet',
#  'gave',
#  'include',
#  'idea',
#  'death',
#  'using',
#  'appeared',
#  'talks',
#  'emails',
#  'climate',
#  'accused',
#  'ohio',
#  'cannot',
#  'concerns',
#  'voting',
#  'failed',
#  'protect',
#  'mueller',
#  'freedom',
#  'almost',
#  'human',
#  'means',
#  'step',
#  'tried',
#  'adviser',
#  'term',
#  'name',
#  'capitol',
#  'financial',
#  'isnt',
#  'marriage',
#  'allegations',
#  'talking',
#  'increase',
#  'street',
#  'access',
#  'hill',
#  'immediately',
#  'pressure',
#  'spoke',
#  'serious',
#  'described',
#  'bring',
#  'speaking',
#  'june',
#  'sign',
#  'programs',
#  'remarks',
#  'head',
#  'rate',
#  'either',
#  'opposition',
#  'event',
#  'fire',
#  'bad',
#  'issued',
#  'officer',
#  'david',
#  'virginia',
#  'turn',
#  'needed',
#  'involved',
#  'tell',
#  'july',
#  'millions',
#  'shot',
#  'worked',
#  'stand',
#  'leading',
#  'especially',
#  'yearold',
#  'course',
#  'strategy',
#  'adding',
#  'criminal',
#  'thousands',
#  'problems',
#  'result',
#  'included',
#  'details',
#  'wrong',
#  'cnns',
#  'remain',
#  'crisis',
#  'labor',
#  'global',
#  'thought',
#  'met',
#  'assault',
#  'mike',
#  'ground',
#  'floor',
#  'putin',
#  'charges',
#  'county',
#  'focus',
#  'anyone',
#  'large',
#  'reason',
#  'repeatedly',
#  'woman',
#  'moment',
#  'facebook',
#  'numbers',
#  'recently',
#  'chance',
#  'claims',
#  'similar',
#  'suggested',
#  'additional',
#  'spent',
#  'terrorist',
#  'citizens',
#  'situation',
#  'received',
#  'confirmed',
#  'lives',
#  'biden',
#  'administrations',
#  'hit',
#  'counsel',
#  'east',
#  'students',
#  'happened',
#  'list',
#  'someone',
#  'quickly',
#  'sides',
#  'repeal',
#  'raised',
#  'noted',
#  'ruling',
#  'prime',
#  'wasnt',
#  'became',
#  'cases',
#  'raise',
#  'significant',
#  'benghazi',
#  'documents',
#  'troops',
#  'offered',
#  'area',
#  'shows',
#  'bipartisan',
#  'phone',
#  'soon',
#  'claimed',
#  'higher',
#  'minority',
#  'source',
#  'parties',
#  'review',
#  'agreed',
#  'mark',
#  'everyone',
#  'makes',
#  'stay',
#  'weve',
#  'pm',
#  'comment',
#  'liberal',
#  'effect',
#  'near',
#  'simply',
#  'planned',
#  'pelosi',
#  'th',
#  'although',
#  'kim',
#  'served',
#  'claim',
#  'terrorism',
#  'signed',
#  'mexico',
#  'sexual',
#  'interest',
#  'employees',
#  'tweet',
#  'criticism',
#  'remains',
#  'christie',
#  'james',
#  'youre',
#  'negotiations',
#  'authority',
#  'everything',
#  'agenda',
#  'syrian',
#  'rally',
#  'amendment',
#  'words',
#  'fired',
#  'brought',
#  'september',
#  'seemed',
#  'january',
#  'rule',
#  'follow',
#  'feel',
#  'helped',
#  'base',
#  'room',
#  'offer',
#  'council',
#  'saw',
#  'delegates',
#  'longer',
#  'level',
#  'happen',
#  'growth',
#  'friends',
#  'medical',
#  'approach',
#  'peace',
#  'presidency',
#  'opportunity',
#  'energy',
#  'argued',
#  'challenge',
#  'ted',
#  'bills',
#  'denied',
#  'short',
#  'turned',
#  'allowed',
#  'expressed',
#  'fiscal',
#  'particularly',
#  'robert',
#  'results',
#  'heard',
#  'publicly',
#  'european',
#  'religious',
#  'live',
#  'meanwhile',
#  'announcement',
#  'difficult',
#  'building',
#  'reid',
#  'ways',
#  'true',
#  'certain',
#  'return',
#  'al',
#  'started',
#  'agencies',
#  'korean',
#  'sources',
#  'opinion',
#  'courts',
#  'deputy',
#  'sought',
#  'push',
#  'emergency',
#  'chris',
#  'warned',
#  'organization',
#  'aides',
#  'lawyer',
#  'half',
#  'third',
#  'ask',
#  'inside',
#  'un',
#  'terms',
#  'previous',
#  'education',
#  'afternoon',
#  'impact',
#  'jeff',
#  'beyond',
#  'benefits',
#  'tough',
#  'rates',
#  'individual',
#  'king',
#  'relationship',
#  'central',
#  'campaigns',
#  'attention',
#  'brown',
#  'prevent',
#  'schumer',
#  'october',
#  'answer',
#  'understand',
#  'related',
#  'probably',
#  'perhaps',
#  'cost',
#  'investigators',
#  'relations',
#  'graham',
#  'statements',
#  'believed',
#  'agree',
#  'protesters',
#  'income',
#  'movement',
#  'measures',
#  'april',
#  'victims',
#  'willing',
#  'caucus',
#  'college',
#  'mean',
#  'elected',
#  'seeking',
#  'decades',
#  'proposed',
#  'crowd',
#  'fighting',
#  'series',
#  'previously',
#  'choice',
#  'knew',
#  'father',
#  'account',
#  'reporting',
#  'example',
#  'attempt',
#  'battle',
#  'avoid',
#  'reach',
#  'market',
#  'ability',
#  'representative',
#  'eight',
#  'december',
#  'events',
#  'paid',
#  'probe',
#  'cohen',
#  'amid',
#  'giving',
#  'parents',
#  'sense',
#  'critics',
#  'ive',
#  'risk',
#  'partys',
#  'wife',
#  'speak',
#  'test',
#  'pence',
#  'evening',
#  'visit',
#  'died',
#  'due',
#  'mayor',
#  'board',
#  'create',
#  'weekend',
#  'critical',
#  'certainly',
#  'decided',
#  'watch',
#  'americas',
#  'individuals',
#  'august',
#  'lower',
#  'records',
#  'scott',
#  'hide',
#  'safety',
#  'provided',
#  'travel',
#  'seems',
#  'hundreds',
#  'status',
#  'son',
#  'secret',
#  'dead',
#  'businesses',
#  'growing',
#  'water',
#  'wisconsin',
#  'terror',
#  'declined',
#  'website',
#  'politico',
#  'reached',
#  'total',
#  'kerry',
#  'industry',
#  'path',
#  'leaving',
#  'consider',
#  'fear',
#  'largely',
#  'favor',
#  'joe',
#  'directly',
#  'stage',
#  'exchange',
#  'host',
#  'manafort',
#  'considered',
#  'confirmation',
#  'appears',
#  'governments',
#  'whats',
#  'pentagon',
#  'seven',
#  'fall',
#  'wouldnt',
#  'hand',
#  'hands',
#  'criticized',
#  'deficit',
#  'play',
#  'biggest',
#  'surveillance',
#  'mass',
#  'crime',
#  'declared',
#  'kelly',
#  'build',
#  'network',
#  'foundation',
#  'research',
#  'cause',
#  'fellow',
#  'old',
#  'tariffs',
#  'hampshire',
#  'forced',
#  'internet',
#  'front',
#  'love',
#  'respond',
#  'ready',
#  'summit',
#  'abortion',
#  'television',
#  'legislative',
#  'permission',
#  'protest',
#  'single',
#  'communications',
#  'paris',
#  'ambassador',
#  'chinese',
#  'serve',
#  'voter',
#  ...]

# %%
# Extract most important features from the Random Forest Classifier Model
feat_imp = tf_rf_model.featureImportances

# %%
# Extract the important features or words along with their importance values in
# a dataframe
rf_fea_imp = pd.DataFrame(zip(vocab, feat_imp.values), columns=['vocab', 'values']).sort_values(by = 'values', ascending=False)

# %%
# Take top 20 values and corresponding vocab
top_20 = rf_fea_imp.head(20)

# Plot top 20 values corresponding to vocab
plt.figure(figsize=(10, 6))
plt.barh(top_20['vocab'], top_20['values'], color='skyblue')
plt.xlabel('Feature Importance')
plt.title('Top 20 Feature Importances')
plt.gca().invert_yaxis()  # Invert y-axis to have the highest feature at the top
plt.tight_layout()
plt.show()

# %% [markdown]
# #### NYT API Demostration (Unsupervised)

# %%
# The API Key
api_key = "your_api_key"

# %%
# Create a new NYTAPI object with your API key.
nyt = NYTAPI(api_key, parse_dates=True)

# %%
# Get the top stories from NYT
top_stories = nyt.top_stories(section = "politics")

# %%
# View
top_stories
# Out:
# [{'section': 'us',
#   'subsection': 'politics',
#   'title': 'House Passes Defense Bill, Clearing It for Biden',
#   'abstract': 'Republicans and Democrats banded together to push through the legislation over the objections of right-wing lawmakers, who had sought abortion, transgender care and diversity restrictions.',
#   'url': 'https://www.nytimes.com/2023/12/14/us/politics/defense-bill-congress.html',
#   'uri': 'nyt://article/e7611600-f736-5e64-9d36-f5b82deb678e',
#   'byline': 'By Karoun Demirjian',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 14, 11, 37, 45, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 14, 10, 47, 9, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 14, 10, 47, 9, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Federal Budget (US)',
#    'Law and Legislation',
#    'United States Defense and Military Forces',
#    'United States Politics and Government'],
#   'org_facet': ['House of Representatives',
#    'Democratic Party',
#    'Republican Party'],
#   'per_facet': [],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/14/multimedia/14dc-defensebill-mzlf/14dc-defensebill-mzlf-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'This year’s defense bill authorizes a 5.2 percent pay increase for service members and civilian employees of the Pentagon and invests in a variety of measures to improve competition with Russia and China.',
#     'copyright': 'Haiyun Jiang/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/14/multimedia/14dc-defensebill-mzlf/14dc-defensebill-mzlf-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'This year’s defense bill authorizes a 5.2 percent pay increase for service members and civilian employees of the Pentagon and invests in a variety of measures to improve competition with Russia and China.',
#     'copyright': 'Haiyun Jiang/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/14/multimedia/14dc-defensebill-mzlf/14dc-defensebill-mzlf-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'This year’s defense bill authorizes a 5.2 percent pay increase for service members and civilian employees of the Pentagon and invests in a variety of measures to improve competition with Russia and China.',
#     'copyright': 'Haiyun Jiang/The New York Times'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'U.S. Naval Officer Is Released From Jail in Japan After Yearslong Effort',
#   'abstract': 'The fallout over the case has strained diplomatic ties between Japan and the United States.',
#   'url': 'https://www.nytimes.com/2023/12/14/us/politics/alkonis-us-japan.html',
#   'uri': 'nyt://article/438bcf97-ef66-5cfc-9c13-b1ab899cd628',
#   'byline': 'By Michael D. Shear',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 14, 10, 25, 50, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 14, 9, 56, 2, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 14, 9, 56, 2, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Prisons and Prisoners',
#    'Sentences (Criminal)',
#    'United States International Relations',
#    'United States Defense and Military Forces',
#    'United States Politics and Government',
#    'Traffic Accidents and Safety'],
#   'org_facet': ['United States Navy', 'Justice Department'],
#   'per_facet': ['Alkonis, Ridge'],
#   'geo_facet': ['Japan'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/14/multimedia/14dc-alkonis-mbjg/14dc-alkonis-mbjg-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Derek and Suzi Alkonis holding a portrait of their son, Lt. Ridge Alkonis.',
#     'copyright': 'Denis Poroy/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2023/12/14/multimedia/14dc-alkonis-mbjg/14dc-alkonis-mbjg-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Derek and Suzi Alkonis holding a portrait of their son, Lt. Ridge Alkonis.',
#     'copyright': 'Denis Poroy/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2023/12/14/multimedia/14dc-alkonis-mbjg/14dc-alkonis-mbjg-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Derek and Suzi Alkonis holding a portrait of their son, Lt. Ridge Alkonis.',
#     'copyright': 'Denis Poroy/Associated Press'}],
#   'short_url': ''},
#  {'section': 'business',
#   'subsection': '',
#   'title': 'U.S. Tax Credits to Spur Clean Energy Face Scrutiny Over Chinese Investments',
#   'abstract': 'The Treasury Department pledged to carefully scrutinize foreign investments in the United States for national security threats.',
#   'url': 'https://www.nytimes.com/2023/12/14/business/clean-energy-tax-credits-chinese-investment.html',
#   'uri': 'nyt://article/5a1b9299-f7db-5f75-90f3-e54aa9330b29',
#   'byline': 'By Alan Rappeport',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 14, 10, 58, 12, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 14, 8, 45, 7, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 14, 8, 45, 7, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Tax Credits, Deductions and Exemptions',
#    'Foreign Investments',
#    'Alternative and Renewable Energy',
#    'Electric and Hybrid Vehicles',
#    'Inflation Reduction Act of 2022'],
#   'org_facet': ['Treasury Department'],
#   'per_facet': [],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/14/multimedia/14dc-taxcredits-zpmw/14dc-taxcredits-zpmw-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 2048,
#     'width': 1366,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'First Solar makes solar panels in Ohio. The incentives are intended to encourage businesses to produce solar panels, process minerals and make electric vehicle components in the United States.',
#     'copyright': 'Daniel Lozada for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/14/multimedia/14dc-taxcredits-zpmw/14dc-taxcredits-zpmw-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'First Solar makes solar panels in Ohio. The incentives are intended to encourage businesses to produce solar panels, process minerals and make electric vehicle components in the United States.',
#     'copyright': 'Daniel Lozada for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/14/multimedia/14dc-taxcredits-zpmw/14dc-taxcredits-zpmw-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'First Solar makes solar panels in Ohio. The incentives are intended to encourage businesses to produce solar panels, process minerals and make electric vehicle components in the United States.',
#     'copyright': 'Daniel Lozada for The New York Times'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'Tracking Retirements in the House',
#   'abstract': 'Given Republicans’ razor-thin majority, a recent wave of exits has the potential to lead to a significant shake-up in the 2024 election.',
#   'url': 'https://www.nytimes.com/interactive/2023/12/14/us/politics/congress-retirements.html',
#   'uri': 'nyt://interactive/b38993bb-0944-5952-b31d-776542cd2289',
#   'byline': 'By Albert Sun and Robert Jimison',
#   'item_type': 'Interactive',
#   'updated_date': datetime.datetime(2023, 12, 14, 12, 18, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 14, 5, 3, 47, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 14, 5, 3, 47, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Elections', 'Presidential Election of 2024'],
#   'org_facet': ['Democratic Party',
#    'Republican Party',
#    'House of Representatives'],
#   'per_facet': ['McCarthy, Kevin (1965- )', 'Santos, George (1988- )'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/2023-12-07-congress-retirements-tracker-index/2023-12-07-congress-retirements-tracker-index-superJumbo-v21.png',
#     'format': 'Super Jumbo',
#     'height': 1200,
#     'width': 1800,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/2023-12-07-congress-retirements-tracker-index/2023-12-07-congress-retirements-tracker-index-threeByTwoSmallAt2X-v22.png',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/2023-12-07-congress-retirements-tracker-index/2023-12-07-congress-retirements-tracker-index-thumbLarge-v23.png',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'G.O.P. Support Grows for a House Candidate With a Disputed Military Record',
#   'abstract': 'J.R. Majewski, an ally of former President Donald J. Trump, is seeking to avenge his 13-point loss in the 2022 midterm elections in Ohio.',
#   'url': 'https://www.nytimes.com/2023/12/14/us/politics/majewski-republican-ohio.html',
#   'uri': 'nyt://article/286890f5-1e22-5ff1-91a4-24666f31b9cc',
#   'byline': 'By Neil Vigdor',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 14, 9, 36, 35, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 14, 5, 3, 39, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 14, 5, 3, 39, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Right-Wing Extremism and Alt-Right',
#    'Presidential Election of 2024',
#    'United States Politics and Government',
#    'Midterm Elections (2022)',
#    'Primaries and Caucuses',
#    'Endorsements',
#    'United States Defense and Military Forces',
#    'September 11 (2001)',
#    'Storming of the US Capitol (Jan, 2021)',
#    'Fringe Groups and Movements',
#    'QAnon',
#    'Awards, Decorations and Honors'],
#   'org_facet': ['House of Representatives',
#    'Republican Party',
#    'United States Air Force'],
#   'per_facet': ['Majewski, J R', 'Kaptur, Marcy'],
#   'geo_facet': ['Ohio'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/pol-majewski-topart-cblw/pol-majewski-topart-cblw-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'J.R. Majewski, who lost his race for Congress in the 2022 midterm elections, picked up key Republican endorsements on Monday as he renews his bid for Ohio’s Ninth Congressional District.',
#     'copyright': 'Phillip L. Kaplan/The Blade, via Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/pol-majewski-topart-cblw/pol-majewski-topart-cblw-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'J.R. Majewski, who lost his race for Congress in the 2022 midterm elections, picked up key Republican endorsements on Monday as he renews his bid for Ohio’s Ninth Congressional District.',
#     'copyright': 'Phillip L. Kaplan/The Blade, via Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/pol-majewski-topart-cblw/pol-majewski-topart-cblw-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'J.R. Majewski, who lost his race for Congress in the 2022 midterm elections, picked up key Republican endorsements on Monday as he renews his bid for Ohio’s Ninth Congressional District.',
#     'copyright': 'Phillip L. Kaplan/The Blade, via Associated Press'}],
#   'short_url': ''},
#  {'section': 'technology',
#   'subsection': '',
#   'title': 'State Dept.’s Fight Against Disinformation Comes Under Attack',
#   'abstract': 'The Global Engagement Center has become the focus of Republican-led criticism that the U.S. government coerces social media platforms into removing offensive content.',
#   'url': 'https://www.nytimes.com/2023/12/14/technology/state-department-disinformation-criticism.html',
#   'uri': 'nyt://article/5186380b-aef0-504c-86fd-29e8ff03f803',
#   'byline': 'By Steven Lee Myers',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 14, 9, 26, 47, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 14, 5, 2, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 14, 5, 2, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['United States Politics and Government',
#    'Rumors and Misinformation',
#    'Suits and Litigation (Civil)',
#    'Censorship',
#    'Social Media',
#    'Decisions and Verdicts',
#    'News and News Media',
#    'International Relations',
#    'Freedom of Speech and Expression',
#    'Presidential Election of 2024'],
#   'org_facet': ['House Select Subcommittee on the Weaponization of the Federal Government'],
#   'per_facet': ['Rubin, James P', 'Paxton, Ken'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/12/business/00State-Department-Disinfo-Rubin/00State-Department-Disinfo-Rubin-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'James P. Rubin, the coordinator of the State Department’s Global Engagement Center, disputed the allegations that his organization censored Americans’ comments online.',
#     'copyright': 'Tayfun Salci/Zuma Press Wire'},
#    {'url': 'https://static01.nyt.com/images/2023/12/12/business/00State-Department-Disinfo-Rubin/00State-Department-Disinfo-Rubin-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'James P. Rubin, the coordinator of the State Department’s Global Engagement Center, disputed the allegations that his organization censored Americans’ comments online.',
#     'copyright': 'Tayfun Salci/Zuma Press Wire'},
#    {'url': 'https://static01.nyt.com/images/2023/12/12/business/00State-Department-Disinfo-Rubin/00State-Department-Disinfo-Rubin-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'James P. Rubin, the coordinator of the State Department’s Global Engagement Center, disputed the allegations that his organization censored Americans’ comments online.',
#     'copyright': 'Tayfun Salci/Zuma Press Wire'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'Got Time for Milk? An Overwhelmed House, Somehow, Does.',
#   'abstract': 'With aid to Ukraine and Israel in limbo, a border deal elusive and a mountain of spending legislation left undone, the House turned its attention to whole milk in schools.',
#   'url': 'https://www.nytimes.com/2023/12/13/us/politics/house-congress-milk.html',
#   'uri': 'nyt://article/2d6a45cf-2df1-5775-97db-c3b0d9a75452',
#   'byline': 'By Robert Jimison',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 14, 12, 29, 27, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 13, 20, 58, 8, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 13, 20, 58, 8, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': 'congressional memo',
#   'des_facet': ['Milk',
#    'Law and Legislation',
#    'Diet and Nutrition',
#    'Children and Childhood',
#    'Education (K-12)',
#    'United States Politics and Government'],
#   'org_facet': ['House of Representatives'],
#   'per_facet': ['Foxx, Virginia', 'Obama, Michelle'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-milkmemo-zbvg/13dc-milkmemo-zbvg-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '“The nutrients in whole milk, like protein, calcium and vitamin D, provide the fuel Santa needs to travel the whole globe in one night,” said Representative Virginia Foxx, Republican of North Carolina. “Whole milk is the unsung hero of his Christmas journey.”',
#     'copyright': 'Tom Brenner for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-milkmemo-zbvg/13dc-milkmemo-zbvg-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '“The nutrients in whole milk, like protein, calcium and vitamin D, provide the fuel Santa needs to travel the whole globe in one night,” said Representative Virginia Foxx, Republican of North Carolina. “Whole milk is the unsung hero of his Christmas journey.”',
#     'copyright': 'Tom Brenner for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-milkmemo-zbvg/13dc-milkmemo-zbvg-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '“The nutrients in whole milk, like protein, calcium and vitamin D, provide the fuel Santa needs to travel the whole globe in one night,” said Representative Virginia Foxx, Republican of North Carolina. “Whole milk is the unsung hero of his Christmas journey.”',
#     'copyright': 'Tom Brenner for The New York Times'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'Election Worker Tells Jury: ‘Giuliani Just Messed Me Up’',
#   'abstract': 'Ruby Freeman, one of two Georgia election workers found to have been defamed by Rudolph W. Giuliani, testified at the trial held to set the damages he will have to pay.',
#   'url': 'https://www.nytimes.com/2023/12/13/us/politics/rudy-giuliani-ruby-freeman.html',
#   'uri': 'nyt://article/e4b2744e-e484-562c-a3de-b592b057deba',
#   'byline': 'By Eileen Sullivan',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 13, 23, 26, 57, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 13, 19, 49, 7, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 13, 19, 49, 7, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Presidential Election of 2020',
#    'Compensation for Damages (Law)',
#    'Libel and Slander',
#    'Suits and Litigation (Civil)'],
#   'org_facet': [],
#   'per_facet': ['Freeman, Ruby',
#    'Moss, Shaye',
#    'Giuliani, Rudolph W',
#    'Howell, Beryl A'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-rudy1-ctbw/13dc-rudy1-ctbw-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1366,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Ruby Freeman, left, and her daughter, Shaye Moss, at a White House ceremony honoring them this year. She testified Wednesday that a tweet from Rudolph W. Giuliani led to years of harassment.',
#     'copyright': 'Pete Marovich for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-rudy1-ctbw/13dc-rudy1-ctbw-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Ruby Freeman, left, and her daughter, Shaye Moss, at a White House ceremony honoring them this year. She testified Wednesday that a tweet from Rudolph W. Giuliani led to years of harassment.',
#     'copyright': 'Pete Marovich for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-rudy1-ctbw/13dc-rudy1-ctbw-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Ruby Freeman, left, and her daughter, Shaye Moss, at a White House ceremony honoring them this year. She testified Wednesday that a tweet from Rudolph W. Giuliani led to years of harassment.',
#     'copyright': 'Pete Marovich for The New York Times'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'Inside the Border Talks That Could Decide the Fate of Ukraine Aid',
#   'abstract': 'Negotiators are racing to reach a deal before Congress is expected to head home for the holidays at the end of the week.',
#   'url': 'https://www.nytimes.com/2023/12/13/us/politics/congress-biden-border-ukraine.html',
#   'uri': 'nyt://article/50b5032a-2971-55b1-adff-d8795d201f8c',
#   'byline': 'By Zolan Kanno-Youngs and Karoun Demirjian',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 14, 9, 32, 15, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 13, 19, 31, 54, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 13, 19, 31, 54, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Illegal Immigration',
#    'United States Politics and Government',
#    'Refugees and Displaced Persons',
#    'Asylum, Right of',
#    'Russian Invasion of Ukraine (2022)'],
#   'org_facet': ['Democratic Party',
#    'House of Representatives',
#    'Republican Party',
#    'Senate'],
#   'per_facet': ['Biden, Joseph R Jr'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-immig-mkqv/13dc-immig-mkqv-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Migrants waiting to be processed by U.S. Customs and Border Protection. The White House has signaled that it is open to several Republican immigration proposals, but others could be difficult to accept.',
#     'copyright': 'Eric Gay/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-immig-mkqv/13dc-immig-mkqv-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Migrants waiting to be processed by U.S. Customs and Border Protection. The White House has signaled that it is open to several Republican immigration proposals, but others could be difficult to accept.',
#     'copyright': 'Eric Gay/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-immig-mkqv/13dc-immig-mkqv-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Migrants waiting to be processed by U.S. Customs and Border Protection. The White House has signaled that it is open to several Republican immigration proposals, but others could be difficult to accept.',
#     'copyright': 'Eric Gay/Associated Press'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'Education Dept. Is Investigating Six More Colleges Over Campus Discrimination',
#   'abstract': 'Stanford, Rutgers and U.C.L.A. were among those being looked into as accusations of hateful rhetoric on campuses have led to a spike in inquiries by the agency.',
#   'url': 'https://www.nytimes.com/2023/12/13/us/politics/education-department-campus-discrimination.html',
#   'uri': 'nyt://article/2a858440-a67b-5592-9aca-31453b817a94',
#   'byline': 'By Zach Montague and Tracey Tully',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 13, 16, 20, 15, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 13, 16, 5, 11, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 13, 16, 5, 11, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Colleges and Universities',
#    'Discrimination',
#    'United States Politics and Government',
#    'Jews and Judaism',
#    'Anti-Semitism',
#    'Israel-Gaza War (2023- )'],
#   'org_facet': ['Education Department (US)',
#    'University of California, Los Angeles',
#    'University of California, San Diego',
#    'Rutgers, The State University of New Jersey',
#    'University of Washington',
#    'Whitman College'],
#   'per_facet': [],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-titlevi-chlt/13dc-titlevi-chlt-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The investigations came weeks after the Education Department opened similar inquiries into a number of elite East Coast schools.',
#     'copyright': 'Alisha Jucevic for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-titlevi-chlt/13dc-titlevi-chlt-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The investigations came weeks after the Education Department opened similar inquiries into a number of elite East Coast schools.',
#     'copyright': 'Alisha Jucevic for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-titlevi-chlt/13dc-titlevi-chlt-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The investigations came weeks after the Education Department opened similar inquiries into a number of elite East Coast schools.',
#     'copyright': 'Alisha Jucevic for The New York Times'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'Mort Engelberg, Producer of Hit Films and Presidential Campaigns, Dies at 86',
#   'abstract': 'A celebrated “advance man” — responsible for logistics and camera-ready moments in campaigns — he forged a lasting bond with Bill Clinton.',
#   'url': 'https://www.nytimes.com/2023/12/13/us/politics/mort-engelberg-dead.html',
#   'uri': 'nyt://article/28d6ec76-e872-5f47-aea3-72c3713761dd',
#   'byline': 'By Trip Gabriel',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 13, 15, 39, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 13, 15, 12, 51, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 13, 15, 12, 51, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Deaths (Obituaries)',
#    'Movies',
#    'Presidential Election of 1992',
#    'United States Politics and Government',
#    'Smokey and the Bandit (Movie)'],
#   'org_facet': [],
#   'per_facet': ['Engelberg, Mort (1937-2023)', 'Clinton, Bill'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/14/multimedia/12engelberg-01-zfpg-print1-SUB/12engelberg-01-zfpg-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1584,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Mort Engelberg and President Bill Clinton in the Oval Office on Nov. 12, 1993.',
#     'copyright': 'Clinton Presidential Library/Sharon Farmer'},
#    {'url': 'https://static01.nyt.com/images/2023/12/14/multimedia/12engelberg-01-zfpg-print1-SUB/12engelberg-01-zfpg-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Mort Engelberg and President Bill Clinton in the Oval Office on Nov. 12, 1993.',
#     'copyright': 'Clinton Presidential Library/Sharon Farmer'},
#    {'url': 'https://static01.nyt.com/images/2023/12/14/multimedia/12engelberg-01-zfpg-print1-SUB/12engelberg-01-zfpg-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Mort Engelberg and President Bill Clinton in the Oval Office on Nov. 12, 1993.',
#     'copyright': 'Clinton Presidential Library/Sharon Farmer'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'Democrats Seize on Texas Case in Push for Abortion Rights',
#   'abstract': 'Democratic candidates jumped on the story of a woman who left Texas for an abortion as a cautionary tale for voters, and Republicans were largely silent.',
#   'url': 'https://www.nytimes.com/2023/12/13/us/politics/abortion-texas-elections.html',
#   'uri': 'nyt://article/d94d1cd5-3cf3-5649-a800-31271ef48195',
#   'byline': 'By Lisa Lerer',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 13, 23, 10, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 13, 14, 42, 42, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 13, 14, 42, 42, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Abortion',
#    'Presidential Election of 2024',
#    'Pregnancy and Childbirth',
#    "Dobbs v Jackson Women's Health Organization (Supreme Court Decision)",
#    'Midterm Elections (2022)'],
#   'org_facet': [],
#   'per_facet': ['Cox, Kate (1992- )'],
#   'geo_facet': ['Texas'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13pol-abortion-02-pzwj/13pol-abortion-02-pzwj-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 2048,
#     'width': 1369,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'A lawsuit by Kate Cox was one of the first attempts by an individual woman to challenge the enforcement of abortion bans put in place by Republican states after Roe v. Wade was overturned a year and a half ago.',
#     'copyright': 'Kate Cox, via Reuters'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13pol-abortion-02-pzwj/13pol-abortion-02-pzwj-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'A lawsuit by Kate Cox was one of the first attempts by an individual woman to challenge the enforcement of abortion bans put in place by Republican states after Roe v. Wade was overturned a year and a half ago.',
#     'copyright': 'Kate Cox, via Reuters'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13pol-abortion-02-pzwj/13pol-abortion-02-pzwj-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'A lawsuit by Kate Cox was one of the first attempts by an individual woman to challenge the enforcement of abortion bans put in place by Republican states after Roe v. Wade was overturned a year and a half ago.',
#     'copyright': 'Kate Cox, via Reuters'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'QAnon Supporter Pours Cash Into a Legal-Defense Fund for Trump Allies',
#   'abstract': 'The fund, meant to help pay the mounting legal bills of people connected to investigations into Donald Trump, has raised more than $1.6 million, a new filing showed.',
#   'url': 'https://www.nytimes.com/2023/12/13/us/politics/trump-legal-defense-fund-qanon.html',
#   'uri': 'nyt://article/20a7fcd5-c2d0-5e40-9346-8996b95345bb',
#   'byline': 'By Maggie Haberman and Shane Goldmacher',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 14, 11, 41, 49, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 13, 12, 49, 2, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 13, 12, 49, 2, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Presidential Election of 2024', 'QAnon', 'Campaign Finance'],
#   'org_facet': ['Patriot Legal Defense Fund',
#    'Save America PAC',
#    'Internal Revenue Service'],
#   'per_facet': ['Trump, Donald J', 'Glassner, Michael (1963- )'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13pol-trump-fund-topart-tvcj/13pol-trump-fund-topart-tvcj-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1364,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The growing crush of legal bills for former President Donald J. Trump and his allies has been a source of strain within his orbit.',
#     'copyright': 'Doug Mills/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13pol-trump-fund-topart-tvcj/13pol-trump-fund-topart-tvcj-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The growing crush of legal bills for former President Donald J. Trump and his allies has been a source of strain within his orbit.',
#     'copyright': 'Doug Mills/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13pol-trump-fund-topart-tvcj/13pol-trump-fund-topart-tvcj-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The growing crush of legal bills for former President Donald J. Trump and his allies has been a source of strain within his orbit.',
#     'copyright': 'Doug Mills/The New York Times'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'Judge Pauses Trump Election Case Amid Appeal of Immunity Issue',
#   'abstract': 'The decision by the judge to freeze the case came as an appeals court agreed to move quickly in considering the former president’s claims that he is immune from prosecution.',
#   'url': 'https://www.nytimes.com/2023/12/13/us/politics/trump-immunity-decision-election-case.html',
#   'uri': 'nyt://article/29ac58d1-7a24-51a5-8c7e-00d46cdf3a09',
#   'byline': 'By Alan Feuer',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 14, 11, 11, 55, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 13, 12, 9, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 13, 12, 9, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Federal Criminal Case Against Trump (2020 Election Case)',
#    'Presidential Election of 2020',
#    'Presidential Election of 2024',
#    'Immunity from Prosecution'],
#   'org_facet': ['Supreme Court (US)'],
#   'per_facet': ['Smith, Jack (Attorney)',
#    'Trump, Donald J',
#    'Chutkan, Tanya S'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-trump-election-mghv/13dc-trump-election-mghv-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1366,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Former President Donald J. Trump’s lawyers asked a federal appeals court to avoid setting an expedited schedule as it considered whether to dismiss the election subversion charges against him.',
#     'copyright': 'Hilary Swift for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-trump-election-mghv/13dc-trump-election-mghv-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Former President Donald J. Trump’s lawyers asked a federal appeals court to avoid setting an expedited schedule as it considered whether to dismiss the election subversion charges against him.',
#     'copyright': 'Hilary Swift for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-trump-election-mghv/13dc-trump-election-mghv-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Former President Donald J. Trump’s lawyers asked a federal appeals court to avoid setting an expedited schedule as it considered whether to dismiss the election subversion charges against him.',
#     'copyright': 'Hilary Swift for The New York Times'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'Trump and His Allies Descend on Iowa',
#   'abstract': 'The former president will also campaign in New Hampshire and Nevada, a burst of activity less than five weeks before voting begins.',
#   'url': 'https://www.nytimes.com/2023/12/13/us/politics/trump-iowa-primary-campaign.html',
#   'uri': 'nyt://article/cd34aea5-dc64-5d5f-84a1-5f117823767b',
#   'byline': 'By Michael Gold',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 13, 21, 10, 24, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 13, 12, 8, 23, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 13, 12, 8, 23, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Presidential Election of 2024',
#    'Primaries and Caucuses',
#    'United States Politics and Government'],
#   'org_facet': [],
#   'per_facet': ['Trump, Donald J', 'Biden, Joseph R Jr'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13pol-trump-setup-fhvz/13pol-trump-setup-fhvz-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Former President Donald J. Trump during a campaign event in Coralville, Iowa, on Wednesday.',
#     'copyright': 'Jordan Gale for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13pol-trump-setup-fhvz/13pol-trump-setup-fhvz-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Former President Donald J. Trump during a campaign event in Coralville, Iowa, on Wednesday.',
#     'copyright': 'Jordan Gale for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13pol-trump-setup-fhvz/13pol-trump-setup-fhvz-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Former President Donald J. Trump during a campaign event in Coralville, Iowa, on Wednesday.',
#     'copyright': 'Jordan Gale for The New York Times'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'Justices to Decide Scope of Obstruction Charge Central to Trump’s Jan. 6 Case',
#   'abstract': 'A ruling by the Supreme Court could affect the cases of hundreds of people charged in connection with the Capitol attack — and potentially the prosecution of Donald J. Trump.',
#   'url': 'https://www.nytimes.com/2023/12/13/us/politics/trump-supreme-court-jan-6.html',
#   'uri': 'nyt://article/23bf7d73-7158-535f-b435-2c8e4771dd4d',
#   'byline': 'By Alan Feuer and Adam Liptak',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 14, 12, 11, 16, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 13, 11, 30, 32, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 13, 11, 30, 32, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Federal Criminal Case Against Trump (2020 Election Case)',
#    'Storming of the US Capitol (Jan, 2021)',
#    'Decisions and Verdicts',
#    'Presidential Election of 2024',
#    'United States Politics and Government'],
#   'org_facet': ['Supreme Court (US)'],
#   'per_facet': ['Trump, Donald J',
#    'Fisher, Joseph R (1971- )',
#    'Nichols, Carl J'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-scotus-jan6-vwlj/13dc-scotus-jan6-vwlj-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Supporters of President Donald J. Trump stormed the Capitol on Jan. 6, 2021.',
#     'copyright': 'Jason Andrew for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-scotus-jan6-vwlj/13dc-scotus-jan6-vwlj-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Supporters of President Donald J. Trump stormed the Capitol on Jan. 6, 2021.',
#     'copyright': 'Jason Andrew for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-scotus-jan6-vwlj/13dc-scotus-jan6-vwlj-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Supporters of President Donald J. Trump stormed the Capitol on Jan. 6, 2021.',
#     'copyright': 'Jason Andrew for The New York Times'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'Hunter Biden, Defying Deposition Subpoena, Again Offers Public Testimony',
#   'abstract': 'The president’s son appeared at a news conference at the Capitol as House investigators awaited him at a private session he declined to attend. Republicans threatened him with contempt.',
#   'url': 'https://www.nytimes.com/2023/12/13/us/politics/hunter-biden-impeachment-testimony.html',
#   'uri': 'nyt://article/1488166f-9130-5796-a903-911efda8c2b2',
#   'byline': 'By Luke Broadwater',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 13, 18, 28, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 13, 9, 46, 32, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 13, 9, 46, 32, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['United States Politics and Government',
#    'Subpoenas',
#    'Impeachment'],
#   'org_facet': ['Republican Party', 'House of Representatives'],
#   'per_facet': ['Biden, Hunter', 'Biden, Joseph R Jr'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-hunter-wtmq/13dc-hunter-wtmq-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1366,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Hunter Biden has objected to providing private testimony, saying he fears Republicans will selectively leak his remarks and try to distort what he says.',
#     'copyright': 'Kenny Holston/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-hunter-wtmq/13dc-hunter-wtmq-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Hunter Biden has objected to providing private testimony, saying he fears Republicans will selectively leak his remarks and try to distort what he says.',
#     'copyright': 'Kenny Holston/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-hunter-wtmq/13dc-hunter-wtmq-thumbLarge-v2.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Hunter Biden has objected to providing private testimony, saying he fears Republicans will selectively leak his remarks and try to distort what he says.',
#     'copyright': 'Kenny Holston/The New York Times'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'World Bank Warns Record Debt Burdens Haunt Developing Economies',
#   'abstract': 'Surging interest rates and waning financing options threaten a “lost decade” for poor countries.',
#   'url': 'https://www.nytimes.com/2023/12/13/us/politics/world-bank-debt-developing-nations.html',
#   'uri': 'nyt://article/198e0db5-18ba-56a3-ba19-b89f57f86893',
#   'byline': 'By Alan Rappeport',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 14, 12, 19, 45, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 13, 9, 30, 7, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 13, 9, 30, 7, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Developing Countries',
#    'Credit and Debt',
#    'Poverty',
#    'Interest Rates'],
#   'org_facet': ['World Bank'],
#   'per_facet': [],
#   'geo_facet': ['China'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/14/multimedia/13dc-debt-print-mtlp/13dc-debt1-mtlp-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1367,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The World Bank is warning that rising interest rates are making the debt burdens of poorer countries unsustainable.',
#     'copyright': 'Bryan Denton for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/14/multimedia/13dc-debt-print-mtlp/13dc-debt1-mtlp-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The World Bank is warning that rising interest rates are making the debt burdens of poorer countries unsustainable.',
#     'copyright': 'Bryan Denton for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/14/multimedia/13dc-debt-print-mtlp/13dc-debt1-mtlp-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The World Bank is warning that rising interest rates are making the debt burdens of poorer countries unsustainable.',
#     'copyright': 'Bryan Denton for The New York Times'}],
#   'short_url': ''},
#  {'section': 'world',
#   'subsection': 'europe',
#   'title': 'As Russia Gains Confidence, a New Urgency Grips Ukraine',
#   'abstract': 'With Western support for Kyiv softening and Congress holding up urgently needed aid, Vladimir Putin’s bet on outlasting Ukraine and its allies is looking stronger.',
#   'url': 'https://www.nytimes.com/2023/12/13/world/europe/ukraine-under-pressure-russia.html',
#   'uri': 'nyt://article/14d0fd87-b6ff-5a38-a302-d0c6e198df46',
#   'byline': 'By Paul Sonne and Andrew E. Kramer',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 14, 10, 9, 22, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 13, 5, 40, 15, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 13, 5, 40, 15, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Russian Invasion of Ukraine (2022)',
#    'Defense and Military Forces',
#    'Foreign Aid',
#    'United States International Relations'],
#   'org_facet': ['North Atlantic Treaty Organization'],
#   'per_facet': ['Putin, Vladimir V',
#    'Zelensky, Volodymyr',
#    'Biden, Joseph R Jr',
#    'Johnson, Mike (1972- )'],
#   'geo_facet': ['Ukraine', 'Russia', 'United States'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13ukraine-urgency-1-qzbc/13ukraine-urgency-1-qzbc-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1366,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'President Volodymyr Zelensky of Ukraine visited President Biden on Tuesday. Mr. Zelensky also pressed Congress to pass a stalled spending bill that includes $50 billion more in security aid for Ukraine.',
#     'copyright': 'Doug Mills/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13ukraine-urgency-1-qzbc/13ukraine-urgency-1-qzbc-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'President Volodymyr Zelensky of Ukraine visited President Biden on Tuesday. Mr. Zelensky also pressed Congress to pass a stalled spending bill that includes $50 billion more in security aid for Ukraine.',
#     'copyright': 'Doug Mills/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13ukraine-urgency-1-qzbc/13ukraine-urgency-1-qzbc-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'President Volodymyr Zelensky of Ukraine visited President Biden on Tuesday. Mr. Zelensky also pressed Congress to pass a stalled spending bill that includes $50 billion more in security aid for Ukraine.',
#     'copyright': 'Doug Mills/The New York Times'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'Inside the Troll Army Waging Trump’s Online Campaign',
#   'abstract': 'A team of meme-makers has been flooding social media with pro-Trump posts riddled with sexist and racist tropes. Donald Trump is cheering them on.',
#   'url': 'https://www.nytimes.com/2023/12/13/us/politics/trump-meme-trolls-2024.html',
#   'uri': 'nyt://article/b099d718-4fd3-5a08-adf3-943eb58ae3e0',
#   'byline': 'By Ken Bensinger',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 13, 22, 49, 52, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 13, 5, 20, 18, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 13, 5, 20, 18, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Presidential Election of 2024',
#    'Social Media',
#    'Political Advertising',
#    'Podcasts'],
#   'org_facet': ['Federal Election Commission'],
#   'per_facet': ['Biden, Joseph R Jr',
#    'DeSantis, Casey',
#    'DeSantis, Ron',
#    'Haley, Nikki R',
#    'Trump, Donald J'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/05/multimedia/00pol-Trump-Memes-qltk/00pol-Trump-Memes-qltk-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1366,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Mr. Trump has helped spread memes that traffic in misinformation, artificial intelligence and deepfakes. The meme-makers are “single-handedly changing the landscape of politics and social media,” a Trump adviser said. ',
#     'copyright': 'Jordan Gale for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/05/multimedia/00pol-Trump-Memes-qltk/00pol-Trump-Memes-qltk-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Mr. Trump has helped spread memes that traffic in misinformation, artificial intelligence and deepfakes. The meme-makers are “single-handedly changing the landscape of politics and social media,” a Trump adviser said. ',
#     'copyright': 'Jordan Gale for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/05/multimedia/00pol-Trump-Memes-qltk/00pol-Trump-Memes-qltk-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Mr. Trump has helped spread memes that traffic in misinformation, artificial intelligence and deepfakes. The meme-makers are “single-handedly changing the landscape of politics and social media,” a Trump adviser said. ',
#     'copyright': 'Jordan Gale for The New York Times'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'House Approves Biden Impeachment Inquiry as G.O.P. Hunts for an Offense',
#   'abstract': 'Republicans are pushing forward with a formal investigation even though their yearlong scrutiny of the president and his family has turned up no evidence of high crimes or misdemeanors.',
#   'url': 'https://www.nytimes.com/2023/12/13/us/politics/biden-impeachment-inquiry-house-vote.html',
#   'uri': 'nyt://article/65ca4d34-2af6-5992-ae8d-c1b37629d2d1',
#   'byline': 'By Luke Broadwater',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 14, 6, 25, 18, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 13, 5, 3, 38, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 13, 5, 3, 38, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Impeachment',
#    'United States Politics and Government',
#    'Ethics and Official Misconduct'],
#   'org_facet': ['House of Representatives',
#    'House Committee on Oversight and Government Reform',
#    'Republican Party'],
#   'per_facet': ['Biden, Joseph R Jr',
#    'Biden, Hunter',
#    'Jordan, Jim (1964- )',
#    'Comer, James R'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-impeach-sub-tfhb/13dc-impeach-sub-tfhb-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1363,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Representative James R. Comer of Kentucky, left, and Representative Jim Jordan of Ohio, right, are leading the Republican impeachment inquiry.',
#     'copyright': 'Kenny Holston/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-impeach-sub-tfhb/13dc-impeach-sub-tfhb-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Representative James R. Comer of Kentucky, left, and Representative Jim Jordan of Ohio, right, are leading the Republican impeachment inquiry.',
#     'copyright': 'Kenny Holston/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/13/multimedia/13dc-impeach-sub-tfhb/13dc-impeach-sub-tfhb-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Representative James R. Comer of Kentucky, left, and Representative Jim Jordan of Ohio, right, are leading the Republican impeachment inquiry.',
#     'copyright': 'Kenny Holston/The New York Times'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'DeSantis Dismisses One Endorsement (for Haley) and Plays Up Another (for Him)',
#   'abstract': 'At a town hall in Iowa, Ron DeSantis, who has the backing of Iowa’s popular governor, attacked Nikki Haley after she added a key supporter: Gov. Chris Sununu of New Hampshire.',
#   'url': 'https://www.nytimes.com/2023/12/13/us/politics/desantis-cnn-event.html',
#   'uri': 'nyt://article/2c4595d7-a12e-593c-a7b3-caf96be86bc9',
#   'byline': 'By Nicholas Nehamas',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 13, 0, 4, 55, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 13, 0, 4, 55, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 13, 0, 4, 55, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Presidential Election of 2024',
#    'News and News Media',
#    'United States Politics and Government',
#    'Endorsements'],
#   'org_facet': [],
#   'per_facet': ['DeSantis, Ron', 'Haley, Nikki R'],
#   'geo_facet': ['Iowa'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/12/multimedia/12pol-desantis-townhall-hkbg/12pol-desantis-townhall-hkbg-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Gov. Ron DeSantis of Florida has been battling Nikki Haley to become the top Republican to try to challenge Donald J. Trump, the clear front-runner.',
#     'copyright': 'Maansi Srivastava/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/12/multimedia/12pol-desantis-townhall-hkbg/12pol-desantis-townhall-hkbg-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Gov. Ron DeSantis of Florida has been battling Nikki Haley to become the top Republican to try to challenge Donald J. Trump, the clear front-runner.',
#     'copyright': 'Maansi Srivastava/The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/12/multimedia/12pol-desantis-townhall-hkbg/12pol-desantis-townhall-hkbg-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Gov. Ron DeSantis of Florida has been battling Nikki Haley to become the top Republican to try to challenge Donald J. Trump, the clear front-runner.',
#     'copyright': 'Maansi Srivastava/The New York Times'}],
#   'short_url': ''},
#  {'section': 'us',
#   'subsection': 'politics',
#   'title': 'As Biden Struggles With Black Men, Allies Gather at White House',
#   'abstract': 'Aides of the president met with influential Black male Democrats to discuss how to shore up his standing with a crucial group of voters before 2024.',
#   'url': 'https://www.nytimes.com/2023/12/12/us/politics/biden-black-democrats.html',
#   'uri': 'nyt://article/a8dc25b2-6669-5b60-87a2-8cdfc3c462d4',
#   'byline': 'By Reid J. Epstein and Maya King',
#   'item_type': 'Article',
#   'updated_date': datetime.datetime(2023, 12, 12, 20, 31, 43, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'created_date': datetime.datetime(2023, 12, 12, 20, 31, 43, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'published_date': datetime.datetime(2023, 12, 12, 20, 31, 43, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Black People',
#    'Voting and Voters',
#    'Presidential Election of 2024',
#    'United States Politics and Government'],
#   'org_facet': ['Democratic Party'],
#   'per_facet': ['Biden, Joseph R Jr',
#    'Clyburn, James E',
#    'Harrison, Jaime R (1976- )',
#    'Horsford, Steven A',
#    'Trump, Donald J'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2023/12/12/multimedia/12pol-biden-blackdems-topart-cjzm/12pol-biden-blackdems-topart-cjzm-superJumbo.jpg',
#     'format': 'Super Jumbo',
#     'height': 1366,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Recent polls have suggested that President Biden has lost support with Black voters, particularly Black men. ',
#     'copyright': 'Haiyun Jiang for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/12/multimedia/12pol-biden-blackdems-topart-cjzm/12pol-biden-blackdems-topart-cjzm-threeByTwoSmallAt2X.jpg',
#     'format': 'threeByTwoSmallAt2X',
#     'height': 400,
#     'width': 600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Recent polls have suggested that President Biden has lost support with Black voters, particularly Black men. ',
#     'copyright': 'Haiyun Jiang for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2023/12/12/multimedia/12pol-biden-blackdems-topart-cjzm/12pol-biden-blackdems-topart-cjzm-thumbLarge.jpg',
#     'format': 'Large Thumbnail',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Recent polls have suggested that President Biden has lost support with Black voters, particularly Black men. ',
#     'copyright': 'Haiyun Jiang for The New York Times'}],
#   'short_url': ''}]

# %%
# Check the abstract of first
top_stories[0]['abstract']
# Out:
# 'Republicans and Democrats banded together to push through the legislation over the objections of right-wing lawmakers, who had sought abortion, transgender care and diversity restrictions.'

# %%
# Create a dataframe from the top stories in the same format as training data
# so that it can be preprocessed using preprocessing pipeline model
inference_df = spark.createDataFrame(pd.DataFrame([(i['section'],i['abstract'],0) for i in top_stories], columns = ['section', 'content', 'all_sides_bias']))
# Out:
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/pandas/conversion.py:474: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():

# %%
#check
inference_df.show()
# Out:
# +----------+--------------------+--------------+
# |   section|             content|all_sides_bias|
# +----------+--------------------+--------------+
# |        us|Republicans and D...|             0|
# |        us|The fallout over ...|             0|
# |  business|The Treasury Depa...|             0|
# |        us|Given Republicans...|             0|
# |        us|J.R. Majewski, an...|             0|
# |technology|The Global Engage...|             0|
# |        us|With aid to Ukrai...|             0|
# |        us|Ruby Freeman, one...|             0|
# |        us|Negotiators are r...|             0|
# |        us|Stanford, Rutgers...|             0|
# |        us|A celebrated “adv...|             0|
# |        us|Democratic candid...|             0|
# |        us|The fund, meant t...|             0|
# |        us|The decision by t...|             0|
# |        us|The former presid...|             0|
# |        us|A ruling by the S...|             0|
# |        us|The president’s s...|             0|
# |        us|Surging interest ...|             0|
# |     world|With Western supp...|             0|
# |        us|A team of meme-ma...|             0|
# +----------+--------------------+--------------+
# only showing top 20 rows

# %%
#check the schema
inference_df.printSchema()
# Out:
# root
#  |-- section: string (nullable = true)
#  |-- content: string (nullable = true)
#  |-- all_sides_bias: long (nullable = true)

# %%
# Transform the dataframe through the preprocessing pipeline model
nyt_df = preprocessed_model.transform(inference_df)

# %%
# Predict the label for the top stories
nyt_df_pred = tf_rf_model.transform(nyt_df)

# %%
# Get distinct prediction labels
nyt_df_pred.select('prediction_rf').distinct().show()
# Out:
# +-------------+
# |prediction_rf|
# +-------------+
# |          1.0|
# +-------------+

# %% [markdown]
# #### Testing in a Supervised Manner

# %% [markdown]
# We are giving such articles of which we know the bias. The aim is to evaluate how well the model is working. We can analyze the results and based on it tune the model if required.

# %%
# This is an example article of class 'left' bias
text_0 =  """ The meeting in Brussels, less than two weeks into the campaign, illustrates how a counteroffensive born in optimism has failed to deliver its expected punch, generating friction and second-guessing between Washington and Kyiv and raising deeper questions about Ukraine’s ability to retake decisive amounts of territory.

As winter approaches, and the front lines freeze into place, Ukraine’s most senior military officials acknowledge that the war has reached a stalemate.

This examination of the lead-up to Ukraine’s counteroffensive is based on interviews with more than 30 senior officials from Ukraine, the United States and European nations. It provides new insights and previously unreported details about America’s deep involvement in the military planning behind the counteroffensive and the factors that contributed to its disappointments. The second part of this two-part account examines how the battle unfolded on the ground over the summer and fall, and the widening fissures between Washington and Kyiv. Some of the officials spoke on the condition of anonymity to discuss sensitive deliberations.

Key elements that shaped the counteroffensive and the initial outcome include:

● Ukrainian, U.S. and British military officers held eight major tabletop war games to build a campaign plan. But Washington miscalculated the extent to which Ukraine’s forces could be transformed into a Western-style fighting force in a short period — especially without giving Kyiv air power integral to modern militaries.

● U.S. and Ukrainian officials sharply disagreed at times over strategy, tactics and timing. The Pentagon wanted the assault to begin in mid-April to prevent Russia from continuing to strengthen its lines. The Ukrainians hesitated, insisting they weren’t ready without additional weapons and training.

● U.S. military officials were confident that a mechanized frontal attack on Russian lines was feasible with the troops and weapons that Ukraine had. The simulations concluded that Kyiv’s forces, in the best case, could reach the Sea of Azov and cut off Russian troops in the south in 60 to 90 days.

● The United States advocated a focused assault along that southern axis, but Ukraine’s leadership believed its forces had to attack at three distinct points along the 600-mile front, southward toward both Melitopol and Berdyansk on the Sea of Azov and east toward the embattled city of Bakhmut.

● The U.S. intelligence community had a more downbeat view than the U.S. military, assessing that the offensive had only a 50-50 chance of success given the stout, multilayered defenses Russia had built up over the winter and spring.

● Many in Ukraine and the West underestimated Russia’s ability to rebound from battlefield disasters and exploit its perennial strengths: manpower, mines and a willingness to sacrifice lives on a scale that few other countries can countenance.

● As the expected launch of the offensive approached, Ukrainian military officials feared they would suffer catastrophic losses — while American officials believed the toll would ultimately be higher without a decisive assault.

The year began with Western resolve at its peak, Ukrainian forces highly confident and President Volodymyr Zelensky predicting a decisive victory. But now, there is uncertainty on all fronts. Morale in Ukraine is waning. International attention has been diverted to the Middle East. Even among Ukraine’s supporters, there is growing political reluctance to contribute more to a precarious cause. At almost every point along the front, expectations and results have diverged as Ukraine has shifted to a slow-moving dismounted slog that has retaken only slivers of territory.

“We wanted faster results,” Zelensky said in an interview with the Associated Press last week. “From that perspective, unfortunately, we did not achieve the desired results. And this is a fact.”

Together, all these factors make victory for Ukraine far less likely than years of war and destruction.

The campaign’s inconclusive and discouraging early months pose sobering questions for Kyiv’s Western backers about the future, as Zelensky — supported by an overwhelming majority of Ukrainians — vows to fight until Ukraine restores the borders established in its 1991 independence from the Soviet Union.

“That’s going to take years and a lot of blood,” a British security official said, if it’s even possible. “Is Ukraine up for that? What are the manpower implications? The economic implications? Implications for Western support?”

The year now stands to end with Russian President Vladimir Putin more certain than ever that he can wait out a fickle West and fully absorb the Ukrainian territory already seized by his troops."""

# %%
# Create a dataframe
text_0_df = spark.createDataFrame(pd.DataFrame([('random',text_0,0)], columns = ['section', 'content', 'all_sides_bias']))
# Out:
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/pandas/conversion.py:474: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():

# %%
# Preprocess the test data
text_0_df = preprocessed_model.transform(text_0_df)

# Make prediction on the test data
text_0_pred_df = tf_rf_model.transform(text_0_df)

# %%
# Get the prediction output
text_0_pred_df.select('prediction_rf').distinct().show()
# Out:
# +-------------+
# |prediction_rf|
# +-------------+
# |          0.0|
# +-------------+

# %% [markdown]
# The above results show that the model is able to classify the "left" biased articles properly.

# %%
# This is an example article of class 'right' bias
text_1 =  """An American warship and multiple commercial vessels were attacked in the Red Sea on Sunday, the Pentagon said, in what may mark a major escalation of military activity in the Middle East related to the Israel-Hamas conflict.
"We’re aware of reports regarding attacks on the USS Carney and commercial vessels in the Red Sea and will provide information as it becomes available," the Pentagon said, according to The Associated Press.
The British military said earlier in the day that a suspected drone attack and explosions occurred in the Red Sea, but it did not provide further details.
The Pentagon did not identify a source of the attacks in the Red Sea, but Yemen's Houthi rebels have launched several recent attacks on ships in the region.
The USS Carney has shot down multiple missiles and drones launched from Yemen since Oct. 7, when terrorists from the Gaza Strip invaded Israel and killed about 1,200 people and took 240 others captive.
The Iran-backed group, which the Biden administration delisted as terrorists, has also ramped up attacks on Israel since Oct. 7."""

# %%
# Create a dataframe
text_1_df = spark.createDataFrame(pd.DataFrame([('random',text_1,0)], columns = ['section', 'content', 'all_sides_bias']))
# Out:
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/pandas/conversion.py:474: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():

# %%
# Preprocess the test data
text_1_df = preprocessed_model.transform(text_1_df)

# Make prediction on the test data
text_1_pred_df = tf_rf_model.transform(text_1_df)

# %%
# Get the prediction output
text_1_pred_df.select('prediction_rf').distinct().show()
# Out:
# +-------------+
# |prediction_rf|
# +-------------+
# |          1.0|
# +-------------+

# %% [markdown]
# The above results show that the model is able to classify the "right" biased articles properly.

# %%
# This is an example article of class 'center' bias
text_2 =  """Senate Republicans who are concerned about former President Trump’s viability in a general election now see Nikki Haley as the last, best chance of denying Trump the GOP presidential nomination and averting what they see as a potential general election disaster.
GOP senators who don’t support Trump acknowledge he could win the presidency, given President Biden’s weak job approval ratings, but they view Haley as much more electable because she does not alienate independent and suburban women voters like Trump does.

They are worried that if Trump is the GOP nominee, it could still lead to a disastrous result for their party.
GOP lawmakers recognize that Trump has a commanding lead in GOP primary polls, but many see Haley as a better choice because she does not face Trump’s legal issues that include 91 felony counts in four separate criminal trials.
They also see Haley as a candidate far less likely to blindside them with wild statements or sudden sweeping policy pronouncements that would become political landmines in next year’s battle for the Senate majority.
The growing buzz around Haley comes at a time when many GOP senators are writing off Florida Gov. Ron DeSantis’s chances of staging a comeback.
“She has better prospects than he does because her numbers are going up and his are coming down. Usually, you want to place your bet on someone who is doing better,” said Sen. Mitt Romney (R-Utah), who has urged Republican donors to coalesce around an alternative to Trump as early as possible in next year’s primary.
Senate Republican Whip John Thune (S.D.), who has repeatedly stressed the importance of appealing to moderate and independent voters beyond the GOP’s conservative base, said Haley “seems to be” emerging as the leading alternative to Trump.

“She’s acquitted herself really well in the debates, and I think has done well out on the stump. Part of running for national office — especially in those early states — is relatability, and I think she’s got a good retail political style. Seems to be winning over some people,” he said.
Thune, who initially endorsed Sen. Tim Scott’s (R-S.C.) bid for the nomination, said Trump “starts with a very commanding lead” in national and battleground polls. But he and other senators think the race is still fluid.
“I guess the question is how much she can shift that narrative,” he said.

Senate Republicans are expecting Haley to get more media attention and another possible bump in the polls after the fourth Republican presidential debate, scheduled for Wednesday, Dec. 6, in Tuscaloosa, Ala. That debate is hosted by NewsNation, the sister network to The Hill.
Haley scored points in the earlier debates by going toe-to-toe with businessman Vivek Ramaswamy, who has since lost momentum in the race.
Sen. Mike Rounds (R-S.C.), who also endorsed Scott, said Haley is surging at the right moment a few weeks before the Iowa caucuses, scheduled for Jan. 15.

He thinks Republican voters are starting to think more seriously about shifting away from Trump, though they’re not there yet.
“The Republicans aren’t ready to make changes yet in their decision making — they’re getting closer. So I think her timing is probably pretty key,” Rounds said. “It will depend now on what the other candidates say and whether the other candidates decide they want to continue to battle on.
“After the Iowa caucuses, after New Hampshire, I think this will be narrowed down to a two-person race,” he added. “I think she has momentum.”

Scott dropped out of the race Nov. 13 and former Vice President Mike Pence dropped out Oct. 28. The other remaining candidates, including Ramaswamy, former New Jersey Gov. Chris Christie and North Dakota Gov. Doug Burgum, are polling in the mid to low single digits in national polls.
Haley’s biggest problem for the much of the past year is that she was stuck behind DeSantis as the leading alternative to Trump. But now that has changed, GOP senators say, and the new pecking order was underscored last week when Americans For Prosperity, the political arm of the powerful Koch network, endorsed Haley.
“I do believe that she’s starting to move ahead. To use the [Formula 1 racing] analogy, she’s probably in the P2 position now, moved up ahead of DeSantis,” said Sen. Thom Tillis (R-N.C.), who isn’t making an endorsement in the presidential primary.

Tillis said Americans For Prosperity has “a pretty good ground game,” which could help Haley turn out voters in key primary states.
“If DeSantis doesn’t perform in Iowa, and she does, then it sets her up for New Hampshire, and it becomes an interesting contest,” he added.
Tillis said DeSantis “peaked early and probably was playing it a little bit too safe at a time when he could have had a breakout moment.”

“Using a Florida, NASA analogy, I think the launch window has passed,” he added. “I wouldn’t count out Nikki Haley. She came in as governor [of South Carolina] the year I came in as Speaker of the [North Carolina] House, and I have a lot of admiration for the way she led South Carolina.”
DeSantis has put a heavy emphasis on winning Iowa, but even if he does, GOP lawmakers note that victory in the Hawkeye State hasn’t translated into success in other state in recent presidential primaries.
Former Sen. Judd Gregg (R-N.H.), who endorsed Haley in October, described her as the only candidate to capture the imagination and interest of people who doubt or don’t want Trump as a nominee.
“If we want to win the presidency, she’s the person to do it,” he said. “All swing states are determined by the independent voters. Most independents today, at least in New Hampshire, are educated women. They won’t vote for Trump under any circumstance.”
Gregg said he doesn’t see DeSantis making a comeback in New Hampshire, even if he wins Iowa.

shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown shutdown border border border border border border border border border border border border border border border border border.

“Iowa has never had a huge impact on downfield primaries,” he said. “Iowa picks corn and New Hampshire wins presidents. … If you look historically, the person who comes out of Iowa [as the winner] doesn’t go very far, unless they’re the perceived front-runner.”
Texas Sen. Ted Cruz (R) won the Iowa caucuses in 2016, and former Sen. Rick Santorum (R-Pa.) and former Arkansas Gov. Mike Huckabee (R) won them in 2012 and 2008, respectively.
Some senators think Trump’s sudden declaration that he would make another attempt to repeal the Affordable Care Act if elected was an attempt to burnish his conservative credentials and paint Haley as a moderate.
“I think he’s going to be more concerned about Nikki Haley getting the support that she has from the Koch group, so you’re going to see him trying to do things to activate his base of support,” Romney predicted.
Haley is now in third place behind Trump and DeSantis, according to an average of recent national polls compiled by Real Clear Politics. But DeSantis’s national poll numbers have dropped substantially since March, and Haley is only a few points behind him.
Several recent polls, including a Washington Post/Monmouth University poll conducted last month, find Haley in second place in New Hampshire, which hosts the second contest of the presidential primary. DeSantis has lagged behind in fourth place in three November polls of New Hampshire voters.
A strong showing in New Hampshire on Jan. 23 would give Haley strong momentum heading into South Carolina’s Feb. 24 primary. She has a home-field advantage in the state after serving as governor from 2011-17.
Since 1980, the winner of the South Carolina Republican presidential primary has gone on to win the party’s nomination every time except for 2012, when former Speaker Newt Gingrich (R-Ga.) won it.
Trump won the South Carolina in 2016 with 33 percent of the vote, while Cruz and Rep. Marco Rubio (R-Fla.) tied for second place with 22 percent each."""

# %%
# Create a dataframe
text_2_df = spark.createDataFrame(pd.DataFrame([('random',text_2,0)], columns = ['section', 'content', 'all_sides_bias']))
# Out:
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/pandas/conversion.py:474: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():

# %%
# Preprocess the test data
text_2_df = preprocessed_model.transform(text_2_df)

# Make prediction on the test data
text_2_pred_df = tf_rf_model.transform(text_2_df)

# %%
# Get the prediction output
text_2_pred_df.select('prediction_rf').distinct().show()
# Out:
# +-------------+
# |prediction_rf|
# +-------------+
# |          0.0|
# +-------------+

# %% [markdown]
# The above results confirms that it is difficult to classify the "center" biased articles as the TF-IDF based model which is a bag of words approach. The words that appear in these articles appear in both "left" and "right" biased articles as it tries to convey opinions of both the sides, making it difficult to classify.

# %% [markdown]
# #### Feature Importance in Multinomial Naive Bayes

# %% [markdown]
# Our aim here is to perform feature importance in Multinomial Naive Bayes model by each class to analyze the most important words or features the model considered for its classification.

# %%
# Extract the coefficient values from the MNB model
mnb_coef = tf_mnb_model.theta.toArray()

# %%
# Create a dataframe with vocab and the coefficient values for "left" biased articles
mnb_left_coef = pd.DataFrame(zip(vocab, mnb_coef[0]), columns=['vocab', 'left_coef']).sort_values(by = 'left_coef', ascending=False)

# Display the first and last 5 rows
display(mnb_left_coef.head())
display(mnb_left_coef.tail())
# Out:
#       vocab  left_coef
# 3        mr  -5.771675
# 1     trump  -6.327954
# 21  clinton  -6.597212
# 7     obama  -6.791712
# 74   police  -6.943871
#                vocab  left_coef
# 50727         candis  -15.38605
# 50725     shaheengop  -15.38605
# 50724        bastins  -15.38605
# 50721  pakistanbased  -15.38605
# 74222     newssurvey  -15.38605

# %%
# Display the top 40 important words/features in "left" biased articles
display(mnb_left_coef.head(40))
# Out:
#            vocab  left_coef
# 3             mr  -5.771675
# 1          trump  -6.327954
# 21       clinton  -6.597212
# 7          obama  -6.791712
# 74        police  -6.943871
# 17   republicans  -7.056826
# 16      campaign  -7.065309
# 19        senate  -7.089970
# 30          bill  -7.108993
# 5          house  -7.153897
# 23     democrats  -7.187557
# 18        states  -7.196266
# 134      sanders  -7.197499
# 29        trumps  -7.211863
# 12         state  -7.219890
# 43        united  -7.222044
# 13    republican  -7.223648
# 62         court  -7.245418
# 72           tax  -7.246357
# 152       romney  -7.253864
# 73        health  -7.257254
# 170         cruz  -7.292076
# 54          vote  -7.296754
# 60         party  -7.305005
# 163          cnn  -7.308968
# 96        voters  -7.315201
# 41       percent  -7.330135
# 113  immigration  -7.334588
# 199          gun  -7.340368
# 14         white  -7.344592
# 24    government  -7.348425
# 79          deal  -7.364068
# 115       debate  -7.369621
# 10        people  -7.370177
# 305           ms  -7.370635
# 101     military  -7.374276
# 4          would  -7.382056
# 47     officials  -7.384161
# 42           law  -7.384873
# 0           said  -7.389961

# %%
# Show them in a list format
", ".join(list(mnb_left_coef.vocab.head(40).values))
# Out:
# 'mr, trump, clinton, obama, police, republicans, campaign, senate, bill, house, democrats, states, sanders, trumps, state, united, republican, court, tax, romney, health, cruz, vote, party, cnn, voters, percent, immigration, gun, white, government, deal, debate, people, ms, military, would, officials, law, said'

# %%
# Create a dataframe with vocab and the coefficient values for "right" biased articles
mnb_right_coef = pd.DataFrame(zip(vocab, mnb_coef[1]), columns=['vocab', 'right_coef']).sort_values(by = 'right_coef', ascending=False)

# Display the first and last 5 records
display(mnb_right_coef.head())
display(mnb_right_coef.tail())
# Out:
#        vocab  right_coef
# 3         mr   -6.049508
# 1      trump   -6.244387
# 270    click   -6.584739
# 41   percent   -6.668764
# 7      obama   -6.696932
#                vocab  right_coef
# 48391      slightfor  -14.729273
# 48392         ignani  -14.729273
# 48393  unpresidented  -14.729273
# 48394        psyched  -14.729273
# 19382         malian  -14.729273

# %%
# Display the top 10 important important words/features for "right" biased articles
display(mnb_right_coef.head(10))
# Out:
#        vocab  right_coef
# 3         mr   -6.049508
# 1      trump   -6.244387
# 270    click   -6.584739
# 41   percent   -6.668764
# 7      obama   -6.696932
# 21   clinton   -6.781358
# 72       tax   -6.964350
# 19    senate   -6.979248
# 179      fox   -6.998827
# 5      house   -7.015170

# %%
# Show them in a list format
", ".join(list(mnb_right_coef.vocab.head(40).values))
# Out:
# 'mr, trump, click, percent, obama, clinton, tax, senate, fox, house, bill, democrats, republicans, police, romney, us, campaign, sanders, court, north, state, government, vote, republican, health, sen, news, cruz, white, security, president, attack, press, report, military, administration, obamacare, federal, spending, law'

# %%
# Create a dataframe with vocab and the coefficient values for "center" biased articles
mnb_center_coef = pd.DataFrame(zip(vocab, mnb_coef[2]), columns=['vocab', 'center_coef']).sort_values(by = 'center_coef', ascending=False)

# Display the first and last 5 records
display(mnb_center_coef.head())
display(mnb_center_coef.tail())
# Out:
#         vocab  center_coef
# 1       trump    -5.813463
# 338  shutdown    -6.683361
# 29     trumps    -6.722085
# 6          us    -6.807430
# 150    border    -6.870730
#             vocab  center_coef
# 39972  villanueva   -14.100638
# 39973     maddows   -14.100638
# 39974      hounds   -14.100638
# 39976    negating   -14.100638
# 74222  newssurvey   -14.100638

# %%
# Display the top 10 important important words/features for "center" biased articles
display(mnb_center_coef.head(10))
# Out:
#         vocab  center_coef
# 1       trump    -5.813463
# 338  shutdown    -6.683361
# 29     trumps    -6.722085
# 6          us    -6.807430
# 150    border    -6.870730
# 3          mr    -6.871435
# 19     senate    -6.899014
# 30       bill    -6.952830
# 5       house    -6.979955
# 62      court    -6.990020

# %%
# Show them in a list format
", ".join(list(mnb_center_coef.vocab.head(40).values))
# Out:
# 'trump, shutdown, trumps, us, border, mr, senate, bill, house, court, trade, kavanaugh, says, clinton, russia, tax, democrats, immigration, police, white, campaign, state, north, investigation, percent, fbi, government, security, russian, election, wall, mueller, congress, republicans, vote, federal, law, said, former, officials'
